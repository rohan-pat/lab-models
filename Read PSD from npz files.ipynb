# %%
import numpy as np

# %%
data = np.load('raw_files/stream0_psd_268.npz')

# %%
data?

# %%
data.files
# Out:
# ['f', 't', 'Z', 'labels']

# %%
data['labels'].shape
# Out:
# (1953, 512)

# %%
data['labels'].dtype
# Out:
# dtype('int8')

# %%
np.unique(data['labels'], return_counts=True)
# Out:
# (array([0, 1, 2, 3], dtype=int8), array([991570,   3938,   2492,   1936]))

# %%
data['labels'] == 1
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
extract_coordinates = np.where(data['labels'] == 1)

# %%
start_x = extract_coordinates[0][0]
end_x = extract_coordinates[0][-1]

start_y = extract_coordinates[1][0]
end_y = extract_coordinates[1][-1]

# %%
print(start_x, start_y, end_x, end_y)
# Out:
# 859 169 1216 179

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(data['labels'].T)

# %%
value1 = data['Z'][start_x: end_x, start_y: end_y]

# %%
val01 = value1[0, :]

# %%
val01
# Out:
# array([0.00076297, 0.00100711, 0.0013123 , 0.00137334, 0.00161749,
#        0.00207527, 0.00247201, 0.00274668, 0.00289927, 0.00329601,
#        0.0044252 , 0.00585958, 0.00729395, 0.0083621 , 0.00888092,
#        0.00863677, 0.00762966, 0.00604269, 0.00412001, 0.00302134,
#        0.0040895 , 0.00607321, 0.00769069, 0.00875884, 0.00894196,
#        0.0083621 , 0.00720239, 0.00585958, 0.0044252 , 0.00341809,
#        0.00302134, 0.00271616, 0.00250253, 0.00204475, 0.00167852,
#        0.00137334, 0.00119023, 0.00109867, 0.00076297], dtype=float32)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(val01)

# %%
for i in range(value1.shape[0]):
    val = value1[i, :]
    plt.plot(val)
plt.show()
